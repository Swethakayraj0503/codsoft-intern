# %% [markdown]
# <a href="https://colab.research.google.com/github/Swethakayraj0503/codsoft-intern/blob/main/Copy_of_advertisement_dataset_CODSOFT_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
x=pd.read_csv("advertising.csv")
print(x)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv("/content/advertising.csv")

df.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df['TV'].plot(color="Grey")
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
df["TV"].plot(kind="kde",figsize=(8,3),color="green")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x="Newspaper",y="Sales",data=df,color="Teal")
plt.show()

# %%
sns.boxplot(x="Newspaper",data=df,color="purple")
plt.show()

# %%
sns.histplot(x="Radio", data=df, color="brown")
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>
